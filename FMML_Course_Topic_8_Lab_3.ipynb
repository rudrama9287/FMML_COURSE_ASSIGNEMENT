# %% [markdown]
# <a href="https://colab.research.google.com/github/rudrama9287/FMML_COURSE_ASSIGNEMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 15:07:40--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   166MB/s    in 0.4s
#
# 2023-05-04 15:07:40 (166 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22250  1510.05078v3  Robust Bayesian models are appealing alternati...  stat
# 6775   1706.00550v3  Deep generative models have achieved impressiv...    cs
# 7219   1711.02545v1  A key challenge in online learning is that cla...  stat
# 37213  1610.09950v2  Most of the existing graph embedding methods f...    cs
# 2486    1307.3964v1  Learning the Markov network structure from dat...    cs
# ...             ...                                                ...   ...
# 35386  cs/0506030v6  The present paper investigates consequence rel...    cs
# 22067   1409.6179v1  Variational inference is a powerful concept th...  stat
# 23049  1802.07535v1  We present a novel model architecture which le...  stat
# 1100   1709.01427v1  When applied to training deep neural networks,...  stat
# 31567  1803.06802v2  Caricature is an art form that expresses subje...    cs
#
#                                                    title  year  \
# 22250      A General Method for Robust Bayesian Modeling  2015
# 6775                  On Unifying Deep Generative Models  2017
# 7219   Online Learning for Changing Environments usin...  2017
# 37213         From Node Embedding To Community Embedding  2016
# 2486   Learning Markov networks with context-specific...  2013
# ...                                                  ...   ...
# 35386  Preferential and Preferential-discriminative C...  2005
# 22067                            Expectation Propagation  2014
# 23049  A Generative Deep Recurrent Model for Exchange...  2018
# 1100   Stochastic Gradient Descent: Going As Fast As ...  2017
# 31567                     Alive Caricature from 2D to 3D  2018
#
#                                                 keywords
# 22250  [appealing, alternatives, providing, protectio...
# 6775   [generative, impressive, generative, adversari...
# 7219   [challenge, classical, algorithms, environment...
# 37213  [embedding, representation, dimensional, embed...
# 2486   [structure, considerable, attention, applicati...
# ...                                                  ...
# 35386  [investigates, consequence, relations, monoton...
# 22067  [variational, inference, underlies, iterative,...
# 23049  [architecture, leverages, inference, dimension...
# 1100   [stochastic, progression, interrupted, catastr...
# 31567  [caricature, expresses, exaggerated, caricatur...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22250    [appealing, alternatives, providing, protectio...
# 6775     [generative, impressive, generative, adversari...
# 7219     [challenge, classical, algorithms, environment...
# 37213    [embedding, representation, dimensional, embed...
# 2486     [structure, considerable, attention, applicati...
#                                ...
# 31379    [classification, convolutional, architecture, ...
# 4155     [detection, annotating, consuming, annotated, ...
# 36805    [investigate, probability, operators, expressi...
# 11029    [determinantal, processes, processes, repulsio...
# 27274    [introduces, framework, arbitrary, detection, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8824 words.
# Out of those 4508 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7866927c-47dc-4df3-b304-9982ab61d8ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7866927c-47dc-4df3-b304-9982ab61d8ee")) {                    Plotly.newPlot(                        "7866927c-47dc-4df3-b304-9982ab61d8ee",                        [{"x":["including","alternatives","developed","approaches","estimation","empirical","providing","connections","probabilistic","regression","computing","historically","assumptions","especially","departures","protection","appealing","considered","extensive","generality","quantitative","formulation","respective","leveraging","mechanism","autoencoders","establishes","paradigms","essentially","adversarial","generated","principled","impressive","directions","experiments","inference","weighting","minimizing","generative","extensions","algorithm","distributions","literatures","respectively","posterior","effectiveness","importance","frameworks","divergences","variational","independent","extending","knowledge","describes","classical","sometimes","complexity","parameter","adaptivity","dependent","outperforms","scenarios","algorithms","challenge","environments","reduction","consecutive","analytics","applications","closeness","representation","optimizes","important","supporting","prediction","community","baselines","proximity","classification","communities","reinforce","dimensional","individual","structure","embedding","application","relations","structures","combining","synthetic","representing","assignments","theoretical","distribution","independences","particular","attention","conditioning","sufficient","guarantees","conditional","underlying","undirected","efficiently","considerable","independence","assignment","formulate","objective","optimization","approximation","intervention","submodular","observational","accelerated","experiment","interventions","performance","experimenter","magnitude","methodology","relationships","extensively","disparate","information","instances","methodologies","framework","interacts","unlabeled","generalization","hypergraph","inability","successful","enumeration","interaction","relational","biological","potential","represent","accurately","introduce","hypergraphs","supervised","hyperspectral","consuming","different","whitening","characterize","relaxation","extremely","competitively","interpreted","semidefinite","enclosing","situations","contribution","nonnegative","preconditioning","enhancing","factorization","projection","ellipsoid","generalize","solutions","identification","equivalent","separable","successive","resolution","constraints","efficient","additional","robustness","approximate","multiplicative","precisions","competing","establishing","distorted","detecting","containing","distortion","demonstrate","reflections","perturbation","distributed","estimates","belonging","correspondences","transformation","reflection","detection","descriptor","riemannian","volumetrically","determining","comparisons","assessment","reference"],"y":[256,26,197,474,225,147,91,61,164,117,113,4,86,118,1,7,14,132,156,11,69,104,12,42,97,24,11,18,29,97,169,19,20,51,569,186,23,41,124,40,818,116,1,86,41,202,80,33,6,60,152,26,361,66,101,30,234,128,3,68,274,108,577,144,82,81,20,19,382,2,358,13,378,34,227,91,62,8,520,21,7,200,121,362,90,236,95,135,113,135,72,15,159,212,3,295,151,15,67,74,94,130,14,162,44,15,29,56,163,326,112,16,6,9,21,63,5,911,1,55,67,71,38,5,758,97,17,543,2,40,109,6,2,65,2,96,32,45,169,105,69,346,8,190,16,36,761,0,50,15,47,3,21,9,2,54,72,8,1,23,44,52,1,62,164,91,57,10,7,132,148,418,118,85,127,10,1,25,17,11,85,48,26,552,6,11,97,70,11,21,66,5,358,27,15,2,39,28,43,45],"type":"bar"},{"x":["including","alternatives","developed","approaches","estimation","empirical","providing","connections ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4508,), (4508, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Competing</span> <span style=''>with</span> <span style=''>wild</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>rules</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>on</span> <span style=''>line</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competitive</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3024691358024691);'>benchmark</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>but</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.8);'>irregular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>rules</span> <span style=''>It</span> <span style=''>is</span> <span style=''>known</span> <span style=''>that</span> <span style=''>if</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3024691358024691);'>benchmark</span> <span style=''>class</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857142);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style=''>there</span> <span style=''>exists</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>whose</span> <span style=''>average</span> <span style=''>loss</span> <span style=''>over</span> <span style=''>the</span> <span style=''>first</span> <span style=''>N</span> <span style=''>examples</span> <span style=''>does</span> <span style=''>not</span> <span style=''>exceed</span> <span style=''>the</span> <span style=''>average</span> <span style=''>loss</span> <span style=''>of</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>rule</span> <span style=''>in</span> <span style=''>the</span> <span style=''>class</span> <span style=''>plus</span> <span style=''>a</span> <span style=''>regret</span> <span style=''>term</span> <span style=''>of</span> <span style=''>O(N(</span> <span style=''>12))</span> <span style=''>The</span> <span style=''>elements</span> <span style=''>of</span> <span style=''>some</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.3024691358024691);'>benchmark</span> <span style=''>classes</span> <span style=''>however</span> <span style=''>are</span> <span style=''>so</span> <span style='background-color:rgba(0, 255, 0, 0.8);'>irregular</span> <span style=''>that</span> <span style=''>these</span> <span style=''>classes</span> <span style=''>are</span> <span style=''>not</span> <span style=''>Hilbert</span> <span style=''>spaces</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>Banach</span> <span style=''>space</span> <span style=''>methods</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style=''>a</span> <span style=''>regret</span> <span style=''>term</span> <span style=''>of</span> <span style=''>O(N(</span> <span style=''>1p))</span> <span style=''>where</span> <span style=''>p</span> <span style=''>is</span> <span style=''>in</span> <span style=''>2infty)</span> <span style=''>and</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Bootstrapped</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>(ABC)</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>(SL)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>have</span> <span style=''>enabled</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>for</span> <span style=''>models</span> <span style=''>that</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>but</span> <span style=''>for</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>cannot</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>pointwise</span> <span style=''>at</span> <span style=''>values</span> <span style=''>of</span> <span style=''>an</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>theta</span> <span style=''>The</span> <span style=''>main</span> <span style=''>idea</span> <span style=''>in</span> <span style=''>ABC</span> <span style=''>and</span> <span style=''>SL</span> <span style=''>is</span> <span style=''>to</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>values</span> <span style=''>of</span> <span style=''>theta</span> <span style=''>(usually</span> <span style=''>chosen</span> <span style=''>using</span> <span style=''>a</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>algorithm)</span> <span style=''>build</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <span style=''>from</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>on</span> <span style=''>theta</span> <span style=''>The</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determines</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style=''>an</span> <span style=''>ABCSL</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>In</span> <span style=''>standard</span> <span style=''>ABCSL</span> <span style=''>the</span> <span style=''>only</span> <span style=''>means</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>at</span> <span style=''>theta</span> <span style=''>is</span> <span style=''>to</span> <span style=''>simulate</span> <span style=''>more</span> <span style=''>times</span> <span style=''>from</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Kernel</span> <span style=''>K</span> <span style=''>Means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>with</span> <span style=''>Nystrom</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximation</span> <span style=''>Relative</span> <span style=''>Error</span> <span style=''>Bounds</span> <br/><br/><span style=''>Kernel</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correctly</span> <span style=''>identify</span> <span style=''>and</span> <span style=''>extract</span> <span style=''>a</span> <span style=''>far</span> <span style=''>more</span> <span style=''>varied</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>cluster</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>than</span> <span style=''>the</span> <span style=''>linear</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>However</span> <span style=''>kernel</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.32539682539682535);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>when</span> <span style=''>the</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>feature</span> <span style=''>map</span> <span style=''>is</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensional</span> <span style=''>and</span> <span style=''>there</span> <span style=''>are</span> <span style=''>many</span> <span style=''>input</span> <span style=''>points</span> <span style=''>Kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>eg</span> <span style=''>the</span> <span style=''>Nystrom</span> <span style=''>method</span> <span style=''>has</span> <span style=''>been</span> <span style=''>applied</span> <span style=''>in</span> <span style=''>previous</span> <span style=''>works</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximately</span> <span style=''>solve</span> <span style=''>kernel</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>when</span> <span style=''>both</span> <span style=''>of</span> <span style=''>the</span> <span style=''>above</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>are</span> <span style=''>present</span> <span style=''>This</span> <span style=''>work</span> <span style=''>analyzes</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paradigm</span> <span style=''>to</span> <span style=''>kernel</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>applying</span> <span style=''>the</span> <span style=''>linear</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>frackepsilon</span> <span style=''>(1</span> <span style=''>o(1))</span> <span style=''>features</span> <span style='background-color:rgba(0, 255, 0, 0.3 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Evaluation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Causal</span> <span style=''>Effect</span> <span style=''>of</span> <span style=''>Control</span> <span style=''>Plans</span> <span style=''>in</span> <span style=''>Nonrecursive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structural</span> <span style=''>Equation</span> <span style=''>Models</span> <br/><br/><span style=''>When</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>studies</span> <span style=''>and</span> <span style=''>a</span> <span style=''>directed</span> <span style=''>cyclic</span> <span style=''>graph</span> <span style=''>for</span> <span style=''>how</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>affect</span> <span style=''>each</span> <span style=''>other</span> <span style=''>is</span> <span style=''>known</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>substantive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style=''>the</span> <span style=''>process</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>which</span> <span style=''>a</span> <span style=''>control</span> <span style=''>plan</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>variable</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conducted</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>bring</span> <span style=''>a</span> <span style=''>response</span> <span style=''>variable</span> <span style=''>close</span> <span style=''>to</span> <span style=''>a</span> <span style=''>target</span> <span style=''>value</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulate</span> <span style=''>an</span> <span style=''>optimal</span> <span style=''>control</span> <span style=''>plan</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>concerning</span> <span style=''>a</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>variable</span> <span style=''>through</span> <span style=''>path</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficients</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>linear</span> <span style=''>nonrecursive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style=''>equation</span> <span style=''>models</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>we</span> <span style=''>clarify</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>causal</span> <span style=''>effects</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conducting</span> <span style=''>a</span> <span style=''>control</span> <span style=''>plan</span> <span style=''>The</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07001082641645616)
# 	segmentation (0.07289787080476362)
# 	experimental (0.13857813063875857)
# 	knowledge (0.1302778780223746)
# 	architecture (0.09346806207145435)
# 	detection (0.12919523637675928)
# 	different (0.27463009743774813)
# 	information (0.2735474557921328)
# 	convolutional (0.13929989173583543)
# 	recognition (0.13713460844460484)
#
# Some Statistics words are:
# 	estimation (0.16658452439625432)
# 	stochastic (0.12764908822079843)
# 	statistical (0.15377033021192707)
# 	algorithm (0.38590438639724)
# 	variables (0.1330704780680138)
# 	theoretical (0.15032035485460818)
# 	distribution (0.18137013307047806)
# 	dimensional (0.1779201577131592)
# 	inference (0.19664859536717594)
# 	regression (0.18137013307047806)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c63839c8-6844-4c15-80ee-043af2d3d4bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c63839c8-6844-4c15-80ee-043af2d3d4bf")) {                    Plotly.newPlot(                        "c63839c8-6844-4c15-80ee-043af2d3d4bf",                        [{"x":["including","alternatives","developed","approaches","estimation","empirical","providing","connections","probabilistic","regression","computing","historically","assumptions","especially","departures","protection","appealing","considered","extensive","generality","quantitative","formulation","respective","leveraging","mechanism","autoencoders","establishes","paradigms","essentially","adversarial","generated","principled","impressive","directions","experiments","inference","weighting","minimizing","generative","extensions","algorithm","distributions","literatures","respectively","posterior","effectiveness","importance","frameworks","divergences","variational","independent","extending","knowledge","describes","classical","sometimes","complexity","parameter","adaptivity","dependent","outperforms","scenarios","algorithms","challenge","environments","reduction","consecutive","analytics","applications","closeness","representation","optimizes","important","supporting","prediction","community","baselines","proximity","classification","communities","reinforce","dimensional","individual","structure","embedding","application","relations","structures","combining","synthetic","representing","assignments","theoretical","distribution","independences","particular","attention","conditioning","sufficient","guarantees","conditional","underlying","undirected","efficiently","considerable","independence","assignment","formulate","objective","optimization","approximation","intervention","submodular","observational","accelerated","experiment","interventions","performance","experimenter","magnitude","methodology","relationships","extensively","disparate","information","instances","methodologies","framework","interacts","unlabeled","generalization","hypergraph","inability","successful","enumeration","interaction","relational","biological","potential","represent","accurately","introduce","hypergraphs","supervised","hyperspectral","consuming","different","whitening","characterize","relaxation","extremely","competitively","interpreted","semidefinite","enclosing","situations","contribution","nonnegative","preconditioning","enhancing","factorization","projection","ellipsoid","generalize","solutions","identification","equivalent","separable","successive","resolution","constraints","efficient","additional","robustness","approximate","multiplicative","precisions","competing","establishing","distorted","detecting","containing","distortion","demonstrate","reflections","perturbation","distributed","estimates","belonging","correspondences","transformation","reflection","detection","descriptor","riemannian","volumetrically","determining","comparisons","assessment","reference","evaluation","consistency","multivariate","coefficients","statistics","benchmark","configuration","statistic","performed","degradation","perception","experimental","furthermore","divergence","generalized","associated","statistical","unexplored","fundamental","validation","deviation","architecture","reinforcement","successfully","estimating","adjustment","surpasses","environment","convolutional","representations","meaningful","retrieval","sentiment","translation","understanding","electronic","embeddings","comparable","paragraphs","similarity","paragraph","applicable","variation","regularization","conditions","functionals","approximations","revisited","clustering","interpretation","equatorial","discovery","phenomena","identifies","unsupervised","variable ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	whitening
# 	truncation
# 	minimizers
# 	statisticians
# 	bernstein
# 	clarifies
# 	gribonval
# 	undersampling
# 	conditionals
# 	hermitian
# 	chronological
# 	misspecification
# 	ingenious
# 	rightarrow
# 	procrustes
# 	subpopulation
# 	behaviorally
# 	quantiles
# 	factorisation
# 	reversing
# Some words which never appear in Statistics papers:
# 	reflections
# 	reflection
# 	volumetrically
# 	paragraphs
# 	paragraph
# 	stylization
# 	photometric
# 	distortions
# 	monocular
# 	personalize
# 	hypertension
# 	superlinear
# 	subjected
# 	illumination
# 	anticipated
# 	comparatively
# 	syntactic
# 	grammatically
# 	syntactically
# 	differentials

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.1038549878949655e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
